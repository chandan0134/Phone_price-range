# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('mobile_price_range_data (2) (1).csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
x=df.iloc[:,:-1] 
y=df.iloc[:,-1] 
print(x.shape)
print(y.shape)
# Out:
# (2000, 20)
# (2000,)

# %%
x.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1500, 20)
# (500, 20)
# (1500,)
# (500,)

# %%
x_train.head()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1890           1991     0          2.8         0   3       1          15
# 35              725     0          1.3         1  16       0          60
# 692             781     0          1.1         0   2       0          38
# 763            1741     1          1.8         0   0       0          14
# 1045            531     0          1.1         0  10       0          63
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# 1890    0.1        181        1  13        298      1037  1861     8     5
# 35      0.4        160        8  17       1134      1249  1326    10     4
# 692     0.4        198        5   7        304      1674  3508    13     8
# 763     0.7        143        8   0        730      1895  3387    11     3
# 1045    0.7        189        7  14        145      1903  2958    17     1
#
#       talk_time  three_g  touch_screen  wifi
# ...

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.preprocessing import StandardScaler   
stx=StandardScaler()
x_train=stx.fit_transform(x_train)
x_test=stx.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression  
m= LogisticRegression()  
m.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred= m.predict(x_test)

# %%
m_pred= m.predict([[750,0,1.5,1,10,1,40,1.2,200,3,20,500,1000,3000,10,10,7,1,1,1]])
print(m_pred)
# Out:
# [3]

# %% [markdown]
# KNN ALGO:

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
m1=KNeighborsClassifier(n_neighbors=15)
m1.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
m1_pred= m1.predict([[750,0,1.5,1,10,1,40,1.2,200,3,20,500,1000,3000,10,10,7,1,1,1]])
print(m1_pred)
# Out:
# [3]
